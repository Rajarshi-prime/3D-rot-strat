# %%
import numpy as np
from matplotlib import pyplot as plt
import pathlib

# %%
N = 384
ro = 0.1
omega = 1.7277
nu = 1e-31
alph = 20
low_wave = False

# %%
if low_wave:
    factor = 1/0.5
    factor1 = 10
    loadPathdata = pathlib.Path(f"/mnt/pfs/rajarshi.chattopadhyay/boussinesq/spectrum-development/nu_{nu}_N_{N}/Ro_{ro}/forcedTide_ring_{omega:.2f}_LW/filtered_flux")
    savePlot = pathlib.Path(f"/mnt/pfs/rajarshi.chattopadhyay/codes/boussinesq/Plots/nu_{nu}_N_{N}/Ro_{ro}/forcedTide_ring_{omega:.2f}_LW/filtered_flux")
    
else:
    factor = 1.0
    factor1 = factor
    loadPathdata = pathlib.Path(f"/mnt/pfs/rajarshi.chattopadhyay/boussinesq/spectrum-development/nu_{nu}_N_{N}/Ro_{ro}/forcedTide_ring_{omega:.2f}/filtered_flux")
    savePlot = pathlib.Path(f"/mnt/pfs/rajarshi.chattopadhyay/codes/boussinesq/Plots/nu_{nu}_N_{N}/Ro_{ro}/forcedTide_ring_{omega:.2f}/filtered_flux")

# %%
Jpdf = np.load(loadPathdata / "JPdfs.npz")

# %%
pi_omg_g = Jpdf['pi_omg_g']
pi_div_h = Jpdf['pi_div_h']

# %%
pi_omg_g = np.log10(np.clip(pi_omg_g, 1e-6, None))
pi_div_h = np.log10(np.clip(pi_div_h, 1e-6, None))
pi_omg_g.shape
# Out:
# (3, 600, 300)

# %%
pi_omg_g.max(), pi_omg_g.std()
# Out:
# (0.0011698209107206294, 4.710784720514689e-05)

# %%
p1 = plt.pcolor(pi_div_h[-1],cmap="copper_r")#,vmax = 1e-2,vmin = 1e-4)
plt.colorbar(p1)
